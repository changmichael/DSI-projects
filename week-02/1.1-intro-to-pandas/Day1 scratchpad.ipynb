# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/Users/michael/DSI-projects/week02/Day1/assets/salary.csv')

# %%
df.head()
# Out:
#        sx    rk  yr         dg  yd     sl
# 0    male  full  25  doctorate  35  36350
# 1    male  full  13  doctorate  22  35350
# 2    male  full  10  doctorate  23  28200
# 3  female  full   7  doctorate  27  26775
# 4    male  full  19    masters  30  33696

# %%
df.head(10)
# Out:
#        sx    rk  yr         dg  yd     sl
# 0    male  full  25  doctorate  35  36350
# 1    male  full  13  doctorate  22  35350
# 2    male  full  10  doctorate  23  28200
# 3  female  full   7  doctorate  27  26775
# 4    male  full  19    masters  30  33696
# 5    male  full  16  doctorate  21  28516
# 6  female  full   0    masters  32  24900
# 7    male  full  16  doctorate  18  31909
# 8    male  full  13    masters  30  31850
# 9    male  full  13    masters  31  32850

# %%
df.describe()
# Out:
#               yr         yd            sl
# count  52.000000  52.000000     52.000000
# mean    7.480769  16.115385  23797.653846
# std     5.507536  10.222340   5917.289154
# min     0.000000   1.000000  15000.000000
# 25%     3.000000   6.750000  18246.750000
# 50%     7.000000  15.500000  23719.000000
# 75%    11.000000  23.250000  27258.500000
# max    25.000000  35.000000  38045.000000

# %%
df.describe(percentiles=[0.10, 0.20, 0.50, 0.80, 0.95])
# Out:
#               yr         yd            sl
# count  52.000000  52.000000     52.000000
# mean    7.480769  16.115385  23797.653846
# std     5.507536  10.222340   5917.289154
# min     0.000000   1.000000  15000.000000
# 10%     1.000000   2.100000  16518.600000
# 20%     2.200000   4.200000  17680.000000
# 50%     7.000000  15.500000  23719.000000
# 80%    11.800000  26.400000  28200.000000
# 95%    16.000000  31.450000  34440.300000
# max    25.000000  35.000000  38045.000000

# %%
df.count()
# Out:
# sx    52
# rk    52
# yr    52
# dg    52
# yd    52
# sl    52
# dtype: int64

# %%
df.mean()
# Out:
# yr        7.480769
# yd       16.115385
# sl    23797.653846
# dtype: float64

# %%
df.median()
# Out:
# yr        7.0
# yd       15.5
# sl    23719.0
# dtype: float64

# %%
df.max()
# Out:
# sx       male
# rk       full
# yr         25
# dg    masters
# yd         35
# sl      38045
# dtype: object

# %%
df.min()
# Out:
# sx       female
# rk    assistant
# yr            0
# dg    doctorate
# yd            1
# sl        15000
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
# sx    52 non-null object
# rk    52 non-null object
# yr    52 non-null int64
# dg    52 non-null object
# yd    52 non-null int64
# sl    52 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 2.5+ KB

# %% [markdown]
# ## Slicing up

# %%
df[0:5]
# Out:
#        sx    rk  yr         dg  yd     sl
# 0    male  full  25  doctorate  35  36350
# 1    male  full  13  doctorate  22  35350
# 2    male  full  10  doctorate  23  28200
# 3  female  full   7  doctorate  27  26775
# 4    male  full  19    masters  30  33696

# %%
df['sx']
# Out:
# 0       male
# 1       male
# 2       male
# 3     female
# 4       male
# 5       male
# 6     female
# 7       male
# 8       male
# 9       male
# 10      male
# 11      male
# 12      male
# 13      male
# 14      male
# 15      male
# 16      male
# 17      male
# 18      male
# 19      male
# 20      male
# 21      male
# 22      male
# 23    female
# 24      male
# 25      male
# 26      male
# 27    female
# 28      male
# 29      male
# 30    female
# 31      male
# 32      male
# 33    female
# 34    female
# 35      male
# 36    female
# 37      male
# 38      male
# 39      male
# 40      male
# 41      male
# 42      male
# 43    female
# 44      male
# 45      male
# 46    female
# 47    female
# 48      male
# 49    female
# 50    female
# 51    female
# Name: sx, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['sx'])
# Out:
# pandas.core.series.Series

# %%
list_of_cols_i_want = ['sx', 'yr', 'sl']

df[list_of_cols_i_want]
# Out:
#         sx  yr     sl
# 0     male  25  36350
# 1     male  13  35350
# 2     male  10  28200
# 3   female   7  26775
# 4     male  19  33696
# 5     male  16  28516
# 6   female   0  24900
# 7     male  16  31909
# 8     male  13  31850
# 9     male  13  32850
# 10    male  12  27025
# 11    male  15  24750
# 12    male   9  28200
# 13    male   9  23712
# 14    male   9  25748
# 15    male   7  29342
# 16    male  13  31114
# 17    male  11  24742
# 18    male  10  22906
# 19    male   6  24450
# 20    male  16  19175
# 21    male   8  20525
# 22    male   7  27959
# 23  female   8  38045
# 24    male   9  24832
# 25    male   5  25400
# 26    male  11  24800
# 27  female   5  25500
# 28    male   3  26182
# 29    male   3  23725
# 30  female  10  21600
# 31    male  11  23300
# 32    male   9  23713
# 33  female   4  20690
# 34  female   6  22450
# 35    male   1  20850
# 36  female   8  18304
# 37    male   4  17095
# 38    male   4  16700
# 39    male   4  17600
# ...

# %% [markdown]
# ## How to pic rows and columns together

# %%
df.iloc[0:10,2:4]
# Out:
#    yr         dg
# 0  25  doctorate
# 1  13  doctorate
# 2  10  doctorate
# 3   7  doctorate
# 4  19    masters
# 5  16  doctorate
# 6   0    masters
# 7  16  doctorate
# 8  13    masters
# 9  13    masters

# %%
df.iloc[1,3]
# Out:
# 'doctorate'

# %% [markdown]
# ## plotting a histogram

# %%
df['yr'].hist()

# %%
df['yr'].hist(figsize=(10,8), color='k')

# %%
fig = df['yr'].hist(figsize=(12,8), color = 'darkorange')
plt.style.use('fivethirtyeight')
ax = plt.gca()
ax.set_ylabel('grequency', fontsize=15)
ax.set_xlabel('years', fontsize=15)
fig.set_title('A chart of stuff', y =1.01)

# %%
swdf = pd.read_csv('/Users/michael/downloads/StarWars.csv', encoding='latin=1')

# %%
swdf.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# ...

# %%
swdf.head(10)
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
# 5  3.292731e+09                                                Yes
# 6  3.292719e+09                                                Yes
# 7  3.292685e+09                                                Yes
# 8  3.292664e+09                                                Yes
# 9  3.292654e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# ...

# %%
swdf.describe()
# Out:
#        RespondentID
# count  1.186000e+03
# mean   3.290128e+09
# std    1.055639e+06
# min    3.288373e+09
# 25%    3.289451e+09
# 50%    3.290147e+09
# 75%    3.290814e+09
# max    3.292880e+09

# %%
swdf.index
# Out:
# RangeIndex(start=0, stop=1187, step=1)

# %%
swdf.count()
# Out:
# RespondentID                                                                                                                                     1186
# Have you seen any of the 6 films in the Star Wars franchise?                                                                                     1187
# Do you consider yourself to be a fan of the Star Wars film franchise?                                                                             837
# Which of the following Star Wars films have you seen? Please select all that apply.                                                               674
# Unnamed: 4                                                                                                                                        572
# Unnamed: 5                                                                                                                                        551
# ...

# %%
swdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187 entries, 0 to 1186
# Data columns (total 38 columns):
# RespondentID                                                                                                                                     1186 non-null float64
# Have you seen any of the 6 films in the Star Wars franchise?                                                                                     1187 non-null object
# Do you consider yourself to be a fan of the Star Wars film franchise?                                                                            837 non-null object
# Which of the following Star Wars films have you seen? Please select all that apply.                                                              674 non-null object
# Unnamed: 4                                                                                                                                       572 non-null object
# ...

# %%
swdf.iloc[0:3,12:20]
# Out:
#                          Unnamed: 12  \
# 0  Star Wars: Episode IV  A New Hope
# 1                                  4
# 2                                NaN
#
#                                     Unnamed: 13  \
# 0  Star Wars: Episode V The Empire Strikes Back
# 1                                             5
# 2                                           NaN
#
#                                 Unnamed: 14  \
# 0  Star Wars: Episode VI Return of the Jedi
# 1                                         6
# 2                                       NaN
#
#   Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.  \
# 0                                           Han Solo
# 1                                     Very favorably
# 2                                                NaN
#
#       Unnamed: 16           Unnamed: 17       Unnamed: 18     Unnamed: 19
# 0  Luke Skywalker  Princess Leia Organa  Anakin Skywalker  Obi Wan Kenobi
# ...

# %%
swdf.iloc[0,19]
# Out:
# 'Obi Wan Kenobi'

# %%
type(swdf)
# Out:
# pandas.core.frame.DataFrame

# %%
type('Education')
# Out:
# str

# %%
type('Unnamed:')
# Out:
# str

# %%
swdf.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# ...

# %%
type('Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film. ')
# Out:
# str

# %%
swdf.iloc[5,3]
# Out:
# 'Star Wars: Episode I  The Phantom Menace'

# %%
swdf.iloc[1,4]
# Out:
# 'Star Wars: Episode II  Attack of the Clones'

# %%
swdf.iloc[1,5]
# Out:
# 'Star Wars: Episode III  Revenge of the Sith'

# %%
swdf.iloc[1,1]
# Out:
# 'Yes'

# %%
swdf.iloc[0,0]
# Out:
# nan

# %%
swdf.iloc[1,6]
# Out:
# 'Star Wars: Episode IV  A New Hope'

# %%
swdf.columns[0:3]
# Out:
# Index([u'RespondentID',
#        u'Have you seen any of the 6 films in the Star Wars franchise?',
#        u'Do you consider yourself to be a fan of the Star Wars film franchise?'],
#       dtype='object')

# %%
swdf.index
# Out:
# RangeIndex(start=0, stop=1187, step=1)

# %%
cols = [x for x in swdf.columns if 'Do' in x]

# %%
cols
# Out:
# [u'Do you consider yourself to be a fan of the Star Wars film franchise?',
#  u'Do you consider yourself to be a fan of the Expanded Universe?\x8c\xe6',
#  u'Do you consider yourself to be a fan of the Star Trek franchise?']

# %%
swdf.loc[:,cols]
# Out:
#      Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                              Response
# 1                                                   Yes
# 2                                                   NaN
# 3                                                    No
# 4                                                   Yes
# 5                                                   Yes
# 6                                                   Yes
# 7                                                   Yes
# 8                                                   Yes
# 9                                                   Yes
# 10                                                   No
# 11                                                  NaN
# 12                                                  NaN
# 13                                                   No
# 14                                                  Yes
# ...

# %%
swdf.iloc[:,1]
# Out:
# 0       Response
# 1            Yes
# 2             No
# 3            Yes
# 4            Yes
# 5            Yes
# 6            Yes
# 7            Yes
# 8            Yes
# 9            Yes
# 10           Yes
# 11           Yes
# 12            No
# 13           Yes
# 14           Yes
# 15           Yes
# 16           Yes
# 17           Yes
# 18           Yes
# 19           Yes
# 20           Yes
# 21           Yes
# 22           Yes
# 23           Yes
# 24           Yes
# 25           Yes
# 26            No
# 27           Yes
# 28           Yes
# 29           Yes
#           ...
# 1157         Yes
# 1158          No
# 1159         Yes
# 1160          No
# 1161         Yes
# 1162         Yes
# 1163         Yes
# 1164         Yes
# 1165         Yes
# 1166         Yes
# 1167         Yes
# 1168         Yes
# 1169          No
# 1170         Yes
# 1171          No
# 1172         Yes
# 1173         Yes
# 1174         Yes
# 1175         Yes
# 1176         Yes
# 1177         Yes
# ...

# %% [markdown]
# ## iloc is using the number, and loc is using the name

# %% [markdown]
# ## Adding a column

# %%
swdf['YesNo'] = 1

# %%
swdf.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                Yes
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1           Star Wars: Episode I  The Phantom Menace
# ...

# %% [markdown]
# ### Study Design
